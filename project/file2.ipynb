# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
rules = pd.read_csv("associationRules.csv")
rules
# Out:
#      Unnamed: 0                                        antecedents  \
# 0             0     frozenset({'60 cake cases dolly girl design'})
# 1             1         frozenset({'60 teatime fairy cake cases'})
# 2             2      frozenset({'alarm clock bakelike chocolate'})
# 3             3      frozenset({'alarm clock bakelike chocolate'})
# 4             4          frozenset({'alarm clock bakelike ivory'})
# ..          ...                                                ...
# 256         256  frozenset({'roses regency teacup and saucer', ...
# 257         257  frozenset({'lunch bag cars blue', 'lunch bag p...
# 258         258  frozenset({'lunch bag red retrospot', 'lunch b...
# 259         259  frozenset({'lunch bag red retrospot', 'lunch b...
# 260         260  frozenset({'lunch bag cars blue', 'lunch bag p...
#
#                                            consequents  antecedent support  \
# 0       frozenset({'pack of 72 retrospot cake cases'})            0.018525
# 1       frozenset({'pack of 72 retrospot cake cases'})            0.034631
# 2            frozenset({'alarm clock bakelike green'})            0.017150
# 3              frozenset({'alarm clock bakelike red'})            0.017150
# 4            frozenset({'alarm clock bakelike green'})            0.025341
# ..                                                 ...                 ...
# 256  frozenset({'green regency teacup and saucer', ...            0.021273
# 257             frozenset({'lunch bag red retrospot'})            0.014072
# 258             frozenset({'lunch bag pink polkadot'})            0.014072
# 259                 frozenset({'lunch bag cars blue'})            0.016436
# 260             frozenset({'lunch bag  black skull.'})            0.014897
#
#      consequent support   support  confidence       lift  representativity  \
# 0              0.054529  0.010059    0.543027   9.958409               1.0
# 1              0.054529  0.017315    0.500000   9.169355               1.0
# 2              0.042931  0.011379    0.663462  15.454151               1.0
# 3              0.046999  0.011983    0.698718  14.866757               1.0
# 4              0.042931  0.014952    0.590022  13.743501               1.0
# ..                  ...       ...         ...        ...               ...
# 256            0.023747  0.011983    0.563307  23.721504               1.0
# 257            0.069591  0.010334    0.734375  10.552725               1.0
# 258            0.050242  0.010334    0.734375  14.616794               1.0
# 259            0.052111  0.010334    0.628763  12.065874               1.0
# 260            0.057113  0.010334    0.693727  12.146564               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0    0.009049    2.068984       0.916561  0.159686   0.516671    0.363751
# 1    0.015427    1.890941       0.922902  0.241010   0.471163    0.408770
# 2    0.010642    2.843862       0.951613  0.233634   0.648366    0.464253
# 3    0.011177    3.163153       0.949012  0.229715   0.683860    0.476844
# 4    0.013864    2.334438       0.951346  0.280412   0.571631    0.469147
# ..        ...         ...            ...       ...        ...         ...
# 256  0.011478    2.235562       0.978663  0.362729   0.552685    0.533969
# 257  0.009355    3.502716       0.918158  0.140930   0.714507    0.441437
# 258  0.009627    3.575560       0.944882  0.191446   0.720324    0.470032
# 259  0.009478    2.553323       0.932447  0.177526   0.608354    0.413537
# 260  0.009483    3.078583       0.931549  0.167558   0.675175    0.437335
#
# [261 rows x 15 columns]

# %%
rules.drop('Unnamed: 0', axis=1, inplace=True)

# %%
rules
# Out:
#                                            antecedents  \
# 0       frozenset({'60 cake cases dolly girl design'})
# 1           frozenset({'60 teatime fairy cake cases'})
# 2        frozenset({'alarm clock bakelike chocolate'})
# 3        frozenset({'alarm clock bakelike chocolate'})
# 4            frozenset({'alarm clock bakelike ivory'})
# ..                                                 ...
# 256  frozenset({'roses regency teacup and saucer', ...
# 257  frozenset({'lunch bag cars blue', 'lunch bag p...
# 258  frozenset({'lunch bag red retrospot', 'lunch b...
# 259  frozenset({'lunch bag red retrospot', 'lunch b...
# 260  frozenset({'lunch bag cars blue', 'lunch bag p...
#
#                                            consequents  antecedent support  \
# 0       frozenset({'pack of 72 retrospot cake cases'})            0.018525
# 1       frozenset({'pack of 72 retrospot cake cases'})            0.034631
# 2            frozenset({'alarm clock bakelike green'})            0.017150
# 3              frozenset({'alarm clock bakelike red'})            0.017150
# 4            frozenset({'alarm clock bakelike green'})            0.025341
# ..                                                 ...                 ...
# 256  frozenset({'green regency teacup and saucer', ...            0.021273
# 257             frozenset({'lunch bag red retrospot'})            0.014072
# 258             frozenset({'lunch bag pink polkadot'})            0.014072
# 259                 frozenset({'lunch bag cars blue'})            0.016436
# 260             frozenset({'lunch bag  black skull.'})            0.014897
#
#      consequent support   support  confidence       lift  representativity  \
# 0              0.054529  0.010059    0.543027   9.958409               1.0
# 1              0.054529  0.017315    0.500000   9.169355               1.0
# 2              0.042931  0.011379    0.663462  15.454151               1.0
# 3              0.046999  0.011983    0.698718  14.866757               1.0
# 4              0.042931  0.014952    0.590022  13.743501               1.0
# ..                  ...       ...         ...        ...               ...
# 256            0.023747  0.011983    0.563307  23.721504               1.0
# 257            0.069591  0.010334    0.734375  10.552725               1.0
# 258            0.050242  0.010334    0.734375  14.616794               1.0
# 259            0.052111  0.010334    0.628763  12.065874               1.0
# 260            0.057113  0.010334    0.693727  12.146564               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0    0.009049    2.068984       0.916561  0.159686   0.516671    0.363751
# 1    0.015427    1.890941       0.922902  0.241010   0.471163    0.408770
# 2    0.010642    2.843862       0.951613  0.233634   0.648366    0.464253
# 3    0.011177    3.163153       0.949012  0.229715   0.683860    0.476844
# 4    0.013864    2.334438       0.951346  0.280412   0.571631    0.469147
# ..        ...         ...            ...       ...        ...         ...
# 256  0.011478    2.235562       0.978663  0.362729   0.552685    0.533969
# 257  0.009355    3.502716       0.918158  0.140930   0.714507    0.441437
# 258  0.009627    3.575560       0.944882  0.191446   0.720324    0.470032
# 259  0.009478    2.553323       0.932447  0.177526   0.608354    0.413537
# 260  0.009483    3.078583       0.931549  0.167558   0.675175    0.437335
#
# [261 rows x 14 columns]

# %%
rules.index.name = "index"

# %%
rules
# Out:
#                                              antecedents  \
# index
# 0         frozenset({'60 cake cases dolly girl design'})
# 1             frozenset({'60 teatime fairy cake cases'})
# 2          frozenset({'alarm clock bakelike chocolate'})
# 3          frozenset({'alarm clock bakelike chocolate'})
# 4              frozenset({'alarm clock bakelike ivory'})
# ...                                                  ...
# 256    frozenset({'roses regency teacup and saucer', ...
# 257    frozenset({'lunch bag cars blue', 'lunch bag p...
# 258    frozenset({'lunch bag red retrospot', 'lunch b...
# 259    frozenset({'lunch bag red retrospot', 'lunch b...
# 260    frozenset({'lunch bag cars blue', 'lunch bag p...
#
#                                              consequents  antecedent support  \
# index
# 0         frozenset({'pack of 72 retrospot cake cases'})            0.018525
# 1         frozenset({'pack of 72 retrospot cake cases'})            0.034631
# 2              frozenset({'alarm clock bakelike green'})            0.017150
# 3                frozenset({'alarm clock bakelike red'})            0.017150
# 4              frozenset({'alarm clock bakelike green'})            0.025341
# ...                                                  ...                 ...
# 256    frozenset({'green regency teacup and saucer', ...            0.021273
# 257               frozenset({'lunch bag red retrospot'})            0.014072
# 258               frozenset({'lunch bag pink polkadot'})            0.014072
# 259                   frozenset({'lunch bag cars blue'})            0.016436
# 260               frozenset({'lunch bag  black skull.'})            0.014897
#
#        consequent support   support  confidence       lift  representativity  \
# index
# 0                0.054529  0.010059    0.543027   9.958409               1.0
# 1                0.054529  0.017315    0.500000   9.169355               1.0
# 2                0.042931  0.011379    0.663462  15.454151               1.0
# 3                0.046999  0.011983    0.698718  14.866757               1.0
# 4                0.042931  0.014952    0.590022  13.743501               1.0
# ...                   ...       ...         ...        ...               ...
# 256              0.023747  0.011983    0.563307  23.721504               1.0
# 257              0.069591  0.010334    0.734375  10.552725               1.0
# 258              0.050242  0.010334    0.734375  14.616794               1.0
# 259              0.052111  0.010334    0.628763  12.065874               1.0
# 260              0.057113  0.010334    0.693727  12.146564               1.0
#
#        leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# index
# 0      0.009049    2.068984       0.916561  0.159686   0.516671    0.363751
# 1      0.015427    1.890941       0.922902  0.241010   0.471163    0.408770
# 2      0.010642    2.843862       0.951613  0.233634   0.648366    0.464253
# 3      0.011177    3.163153       0.949012  0.229715   0.683860    0.476844
# 4      0.013864    2.334438       0.951346  0.280412   0.571631    0.469147
# ...         ...         ...            ...       ...        ...         ...
# 256    0.011478    2.235562       0.978663  0.362729   0.552685    0.533969
# 257    0.009355    3.502716       0.918158  0.140930   0.714507    0.441437
# 258    0.009627    3.575560       0.944882  0.191446   0.720324    0.470032
# 259    0.009478    2.553323       0.932447  0.177526   0.608354    0.413537
# 260    0.009483    3.078583       0.931549  0.167558   0.675175    0.437335
#
# [261 rows x 14 columns]

# %%
cols  = rules.columns

# %%
first_item =cols[0]
second_item = cols[1]

# %%
second_item
# Out:
# 'consequents'

# %%
antecedents =rules[first_item].apply(extract_content)

# %%
import re

def extract_content(s):
    match = re.search(r"frozenset\(\{?'(.+?)'?\}\)", s)
    return match.group(1) if match else s

# %%
rules[first_item] = antecedents
rules.head()
# Out:
#                            antecedents                      consequents  \
# index
# 0      60 cake cases dolly girl design  pack of 72 retrospot cake cases
# 1          60 teatime fairy cake cases  pack of 72 retrospot cake cases
# 2       alarm clock bakelike chocolate       alarm clock bakelike green
# 3       alarm clock bakelike chocolate         alarm clock bakelike red
# 4           alarm clock bakelike ivory       alarm clock bakelike green
#
#        antecedent support  consequent support   support  confidence  \
# index
# 0                0.018525            0.054529  0.010059    0.543027
# 1                0.034631            0.054529  0.017315    0.500000
# 2                0.017150            0.042931  0.011379    0.663462
# 3                0.017150            0.046999  0.011983    0.698718
# 4                0.025341            0.042931  0.014952    0.590022
#
#             lift  representativity  leverage  conviction  zhangs_metric  \
# index
# 0       9.958409               1.0  0.009049    2.068984       0.916561
# 1       9.169355               1.0  0.015427    1.890941       0.922902
# 2      15.454151               1.0  0.010642    2.843862       0.951613
# 3      14.866757               1.0  0.011177    3.163153       0.949012
# 4      13.743501               1.0  0.013864    2.334438       0.951346
#
#         jaccard  certainty  kulczynski
# index
# 0      0.159686   0.516671    0.363751
# 1      0.241010   0.471163    0.408770
# 2      0.233634   0.648366    0.464253
# 3      0.229715   0.683860    0.476844
# 4      0.280412   0.571631    0.469147

# %%
consequent =rules[second_item].apply(extract_content)

# %%
rules[second_item]= consequent

# %%
rules.head()
# Out:
#                            antecedents                      consequents  \
# index
# 0      60 cake cases dolly girl design  pack of 72 retrospot cake cases
# 1          60 teatime fairy cake cases  pack of 72 retrospot cake cases
# 2       alarm clock bakelike chocolate       alarm clock bakelike green
# 3       alarm clock bakelike chocolate         alarm clock bakelike red
# 4           alarm clock bakelike ivory       alarm clock bakelike green
#
#        antecedent support  consequent support   support  confidence  \
# index
# 0                0.018525            0.054529  0.010059    0.543027
# 1                0.034631            0.054529  0.017315    0.500000
# 2                0.017150            0.042931  0.011379    0.663462
# 3                0.017150            0.046999  0.011983    0.698718
# 4                0.025341            0.042931  0.014952    0.590022
#
#             lift  representativity  leverage  conviction  zhangs_metric  \
# index
# 0       9.958409               1.0  0.009049    2.068984       0.916561
# 1       9.169355               1.0  0.015427    1.890941       0.922902
# 2      15.454151               1.0  0.010642    2.843862       0.951613
# 3      14.866757               1.0  0.011177    3.163153       0.949012
# 4      13.743501               1.0  0.013864    2.334438       0.951346
#
#         jaccard  certainty  kulczynski
# index
# 0      0.159686   0.516671    0.363751
# 1      0.241010   0.471163    0.408770
# 2      0.233634   0.648366    0.464253
# 3      0.229715   0.683860    0.476844
# 4      0.280412   0.571631    0.469147

# %%
rules.to_csv("associationRules.csv")
